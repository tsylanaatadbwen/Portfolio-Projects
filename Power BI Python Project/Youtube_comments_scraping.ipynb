# %%
import googleapiclient.discovery
import pandas as pd

# %% [markdown]
# API key
# AIzaSyBypsDO3ym9jn1wSYpy68yvQoWKSlyBm28

# %%
#since there is no next page token the below code will only return 100 max comments

api_service_name = 'youtube'
api_version = 'v3'
DEVELOPER_KEY = "AIzaSyBypsDO3ym9jn1wSYpy68yvQoWKSlyBm28"

youtube = googleapiclient.discovery.build(api_service_name, api_version,
                                          developerKey= DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part = 'snippet',
    videoId = 'XxOh12Uhg08', #the videO link
    maxResults = 1000
)

response = request.execute()

data = []

for i in response['items']:
    comment = i['snippet']['topLevelComment']['snippet']
    data.append([
        comment['authorDisplayName'],
        comment['publishedAt'],
        comment['updatedAt'],
        comment['likeCount'],
        comment['textDisplay']
    ])

df = pd.DataFrame(data, columns = ['Username', 'Posted_at', 'updated_at', 'like_count', 'comment'])
df
# Out:
#                 Username             Posted_at            updated_at  \
# 0              @DoveBlue  2024-03-23T01:01:45Z  2024-03-23T01:01:45Z
# 1      @tigreytigrey8537  2024-03-22T19:03:49Z  2024-03-22T19:03:49Z
# 2    @shafeekliberty1232  2024-03-22T13:43:55Z  2024-03-22T13:43:55Z
# 3               @jfcomis  2024-03-22T06:08:50Z  2024-03-22T06:08:50Z
# 4   @IstandwithPalestine  2024-03-22T00:33:40Z  2024-03-22T00:33:40Z
# ..                   ...                   ...                   ...
# 95       @foresteyes3398  2024-02-25T10:16:18Z  2024-02-25T10:16:18Z
# 96       @foresteyes3398  2024-02-25T10:15:51Z  2024-02-25T10:15:51Z
# 97              @pytha12  2024-02-25T07:57:28Z  2024-02-25T07:57:28Z
# 98      @sergejpanov5543  2024-02-25T07:31:36Z  2024-02-25T07:31:36Z
# 99       @robertfoertsch  2024-02-25T03:17:39Z  2024-02-25T03:17:51Z
#
#     like_count                                            comment
# 0            0  Where are the Door Handles, and, Why do you ne...
# ...
